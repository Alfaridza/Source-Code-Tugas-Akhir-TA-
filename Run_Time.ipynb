# %% [markdown]
# <a href="https://colab.research.google.com/github/Alfaridza/Source-Code-Tugas-Akhir-TA-/blob/main/Run_Time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Run Time Fungsi Eksponensial

# %%
import matplotlib.pyplot as plt

# Data masalah (problems) dan iterasi untuk setiap metode
problems = ['F_7', 'F_12', 'F_14']
iteration_bisection = [0.00042, 0.00037, 0.00021]
iteration_trisection = [0.00119, 0.00016, 0.01508]
iteration_regula = [0.00165, 0.00930, 0.00356]
iteration_newton = [0.00043, 0.00029, 0.00027]
iteration_hybrid_bisection_regula = [0.00091, 0.01050, 0.00455]
iteration_hybrid_trisection_regula = [0.00039, 0.00287, 0.00106]


# Membuat plot
plt.figure(figsize=(10, 6))

# Plot untuk setiap metode
#plt.plot(problems, iteration_bisection, linestyle='--', marker='o', color='blue', label='Bisection')
#plt.plot(problems, iteration_trisection, linestyle='--', marker='o', color='orange', label='Trisection')
#plt.plot(problems, iteration_regula, linestyle='--', marker='o', color='green', label='Regula Falsi')
#plt.plot(problems, iteration_newton, linestyle='--', marker='o', color='red', label='Newton-Raphson')
plt.plot(problems, iteration_hybrid_bisection_regula, linestyle='-', marker='o', color='purple', label='Hybrid Bisection-Regula Falsi')
#plt.plot(problems, iteration_hybrid_trisection_regula, linestyle='--', marker='o', color='brown', label='Hybrid Trisection-Regula Falsi')

# Menambahkan label pada setiap titik data
for i, value in enumerate(iteration_bisection):
    plt.annotate(f"{value}", (problems[i], iteration_bisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='blue')

for i, value in enumerate(iteration_trisection):
    plt.annotate(f"{value}", (problems[i], iteration_trisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='orange')

#for i, value in enumerate(iteration_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='green')

#for i, value in enumerate(iteration_newton):
 #   plt.annotate(f"{value}", (problems[i], iteration_newton[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='red')

for i, value in enumerate(iteration_hybrid_bisection_regula):
    plt.annotate(f"{value}", (problems[i], iteration_hybrid_bisection_regula[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='purple')

#for i, value in enumerate(iteration_hybrid_trisection_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_hybrid_trisection_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='brown')

# Menambahkan judul dan label sumbu
plt.title('Perbandingan Average Run Time metode algoritma Bisection,Trisection dan hybrid bisection-regula falsi Fungsi Polinomial', fontsize=16, pad=20)
plt.xlabel('Fungsi(f)', fontsize=14, labelpad=15)
plt.ylabel('Average Run Time (s)', fontsize=14, labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Menyesuaikan layout
plt.tight_layout()

# Menampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data masalah (problems) dan iterasi untuk setiap metode
problems = ['F_7', 'F_12', 'F_14']
iteration_bisection = [0.00042, 0.00037, 0.00021]
iteration_trisection = [0.00119, 0.00016, 0.01508]
iteration_regula = [0.00165, 0.00930, 0.00356]
iteration_newton = [0.00043, 0.00029, 0.00027]
iteration_hybrid_bisection_regula = [0.00091, 0.01050, 0.00455]
iteration_hybrid_trisection_regula = [0.00039, 0.00287, 0.00106]


# Membuat plot
plt.figure(figsize=(10, 6))

# Plot untuk setiap metode
plt.plot(problems, iteration_bisection, linestyle='--', marker='o', color='blue', label='Bisection')
plt.plot(problems, iteration_trisection, linestyle='--', marker='o', color='orange', label='Trisection')
#plt.plot(problems, iteration_regula, linestyle='--', marker='o', color='green', label='Regula Falsi')
#plt.plot(problems, iteration_newton, linestyle='--', marker='o', color='red', label='Newton-Raphson')
#plt.plot(problems, iteration_hybrid_bisection_regula, linestyle='-', marker='o', color='purple', label='Hybrid Bisection-Regula Falsi')
plt.plot(problems, iteration_hybrid_trisection_regula, linestyle='--', marker='o', color='brown', label='Hybrid Trisection-Regula Falsi')

# Menambahkan label pada setiap titik data
for i, value in enumerate(iteration_bisection):
    plt.annotate(f"{value}", (problems[i], iteration_bisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='blue')

for i, value in enumerate(iteration_trisection):
    plt.annotate(f"{value}", (problems[i], iteration_trisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='orange')

#for i, value in enumerate(iteration_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='green')

#for i, value in enumerate(iteration_newton):
 #   plt.annotate(f"{value}", (problems[i], iteration_newton[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='red')

#for i, value in enumerate(iteration_hybrid_bisection_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_hybrid_bisection_regula[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='purple')

for i, value in enumerate(iteration_hybrid_trisection_regula):
    plt.annotate(f"{value}", (problems[i], iteration_hybrid_trisection_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='brown')

# Menambahkan judul dan label sumbu
plt.title('Perbandingan Average Run Time metode algoritma Bisection,Trisection dan hybrid bisection-regula falsi Fungsi Polinomial', fontsize=16, pad=20)
plt.xlabel('Fungsi(f)', fontsize=14, labelpad=15)
plt.ylabel('Average Run Time (s)', fontsize=14, labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Menyesuaikan layout
plt.tight_layout()

# Menampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data masalah (problems) dan iterasi untuk setiap metode
problems = ['F_7', 'F_12', 'F_14']
iteration_bisection = [0.00042, 0.00037, 0.00021]
iteration_trisection = [0.00119, 0.00016, 0.01508]
iteration_regula = [0.00165, 0.00930, 0.00356]
iteration_newton = [0.00043, 0.00029, 0.00027]
iteration_hybrid_bisection_regula = [0.00091, 0.01050, 0.00455]
iteration_hybrid_trisection_regula = [0.00039, 0.00287, 0.00106]


# Membuat plot
plt.figure(figsize=(10, 6))

# Plot untuk setiap metode
#plt.plot(problems, iteration_bisection, linestyle='--', marker='o', color='blue', label='Bisection')
#plt.plot(problems, iteration_trisection, linestyle='--', marker='o', color='orange', label='Trisection')
plt.plot(problems, iteration_regula, linestyle='--', marker='o', color='green', label='Regula Falsi')
plt.plot(problems, iteration_newton, linestyle='--', marker='o', color='red', label='Newton-Raphson')
plt.plot(problems, iteration_hybrid_bisection_regula, linestyle='-', marker='o', color='purple', label='Hybrid Bisection-Regula Falsi')
#plt.plot(problems, iteration_hybrid_trisection_regula, linestyle='--', marker='o', color='brown', label='Hybrid Trisection-Regula Falsi')

# Menambahkan label pada setiap titik data
#for i, value in enumerate(iteration_bisection):
 #   plt.annotate(f"{value}", (problems[i], iteration_bisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='blue')

#for i, value in enumerate(iteration_trisection):
   # plt.annotate(f"{value}", (problems[i], iteration_trisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='orange')

for i, value in enumerate(iteration_regula):
    plt.annotate(f"{value}", (problems[i], iteration_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='green')

for i, value in enumerate(iteration_newton):
    plt.annotate(f"{value}", (problems[i], iteration_newton[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='red')

for i, value in enumerate(iteration_hybrid_bisection_regula):
    plt.annotate(f"{value}", (problems[i], iteration_hybrid_bisection_regula[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='purple')

#for i, value in enumerate(iteration_hybrid_trisection_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_hybrid_trisection_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='brown')

# Menambahkan judul dan label sumbu
plt.title('Perbandingan Average Run Time metode algoritma Bisection,Trisection dan hybrid bisection-regula falsi Fungsi Eksponensial', fontsize=16, pad=20)
plt.xlabel('Fungsi(f)', fontsize=14, labelpad=15)
plt.ylabel('Average Run Time (s)', fontsize=14, labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Menyesuaikan layout
plt.tight_layout()

# Menampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data masalah (problems) dan iterasi untuk setiap metode
problems = ['F_7', 'F_12', 'F_14']
iteration_bisection = [0.00042, 0.00037, 0.00021]
iteration_trisection = [0.00119, 0.00016, 0.01508]
iteration_regula = [0.00165, 0.00930, 0.00356]
iteration_newton = [0.00043, 0.00029, 0.00027]
iteration_hybrid_bisection_regula = [0.00091, 0.01050, 0.00455]
iteration_hybrid_trisection_regula = [0.00039, 0.00287, 0.00106]


# Membuat plot
plt.figure(figsize=(10, 6))

# Plot untuk setiap metode
#plt.plot(problems, iteration_bisection, linestyle='--', marker='o', color='blue', label='Bisection')
#plt.plot(problems, iteration_trisection, linestyle='--', marker='o', color='orange', label='Trisection')
plt.plot(problems, iteration_regula, linestyle='--', marker='o', color='green', label='Regula Falsi')
plt.plot(problems, iteration_newton, linestyle='--', marker='o', color='red', label='Newton-Raphson')
#plt.plot(problems, iteration_hybrid_bisection_regula, linestyle='-', marker='o', color='purple', label='Hybrid Bisection-Regula Falsi')
plt.plot(problems, iteration_hybrid_trisection_regula, linestyle='--', marker='o', color='brown', label='Hybrid Trisection-Regula Falsi')

# Menambahkan label pada setiap titik data
#for i, value in enumerate(iteration_bisection):
 #   plt.annotate(f"{value}", (problems[i], iteration_bisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='blue')

#for i, value in enumerate(iteration_trisection):
   # plt.annotate(f"{value}", (problems[i], iteration_trisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='orange')

for i, value in enumerate(iteration_regula):
    plt.annotate(f"{value}", (problems[i], iteration_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='green')

for i, value in enumerate(iteration_newton):
    plt.annotate(f"{value}", (problems[i], iteration_newton[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='red')

#for i, value in enumerate(iteration_hybrid_bisection_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_hybrid_bisection_regula[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='purple')

for i, value in enumerate(iteration_hybrid_trisection_regula):
    plt.annotate(f"{value}", (problems[i], iteration_hybrid_trisection_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='brown')

# Menambahkan judul dan label sumbu
plt.title('Perbandingan Average Run Time metode algoritma Bisection,Trisection dan hybrid Trisectionn-regula falsi Fungsi Eksponensial', fontsize=16, pad=20)
plt.xlabel('Fungsi(f)', fontsize=14, labelpad=15)
plt.ylabel('Average Run Time (s)', fontsize=14, labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Menyesuaikan layout
plt.tight_layout()

# Menampilkan plot
plt.show()

# %% [markdown]
# ## RUN TIME TRIGONOMETRI

# %%
import matplotlib.pyplot as plt

# Data masalah (problems) dan iterasi untuk setiap metode
problems = ['F_8', 'F_9', 'F_10', 'F_13', 'F_15']
iteration_bisection = [0.00031, 0.00022, 0.00034, 0.00043, 0.00021 ]
iteration_trisection = [0.00091, 0.00107, 0.00034 , 0.01217, 0.00300]
iteration_regula = [0.00859, 0.00847, 0.00608 , 0.00941, 0.00311]
iteration_newton = [0.00026 , 0.00036, 0.00043, 0.00041 , 0.00311]
iteration_hybrid_bisection_regula = [0.00111, 0.00582, 0.00082, 0.00070, 0.00066 ]
iteration_hybrid_trisection_regula = [0.00277, 0.00438, 0.00226, 0.00056, 0.00288 ]


# Membuat plot
plt.figure(figsize=(10, 6))

# Plot untuk setiap metode
plt.plot(problems, iteration_bisection, linestyle='--', marker='o', color='blue', label='Bisection')
plt.plot(problems, iteration_trisection, linestyle='--', marker='o', color='orange', label='Trisection')
#plt.plot(problems, iteration_regula, linestyle='--', marker='o', color='green', label='Regula Falsi')
#plt.plot(problems, iteration_newton, linestyle='--', marker='o', color='red', label='Newton-Raphson')
plt.plot(problems, iteration_hybrid_bisection_regula, linestyle='-', marker='o', color='purple', label='Hybrid Bisection-Regula Falsi')
#plt.plot(problems, iteration_hybrid_trisection_regula, linestyle='--', marker='o', color='brown', label='Hybrid Trisection-Regula Falsi')

# Menambahkan label pada setiap titik data
for i, value in enumerate(iteration_bisection):
    plt.annotate(f"{value}", (problems[i], iteration_bisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='blue')

for i, value in enumerate(iteration_trisection):
    plt.annotate(f"{value}", (problems[i], iteration_trisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='orange')

#for i, value in enumerate(iteration_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='green')

#for i, value in enumerate(iteration_newton):
 #   plt.annotate(f"{value}", (problems[i], iteration_newton[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='red')

for i, value in enumerate(iteration_hybrid_bisection_regula):
    plt.annotate(f"{value}", (problems[i], iteration_hybrid_bisection_regula[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='purple')

#for i, value in enumerate(iteration_hybrid_trisection_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_hybrid_trisection_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='brown')

# Menambahkan judul dan label sumbu
plt.title('Perbandingan Average Run Time metode algoritma Bisection,Trisection dan hybrid bisection-regula falsi Fungsi Trigonometri', fontsize=16, pad=20)
plt.xlabel('Fungsi(f)', fontsize=14, labelpad=15)
plt.ylabel('Average Run Time (s)', fontsize=14, labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Menyesuaikan layout
plt.tight_layout()

# Menampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data masalah (problems) dan iterasi untuk setiap metode
problems = ['F_8', 'F_9', 'F_10', 'F_13', 'F_15']
iteration_bisection = [0.00031, 0.00022, 0.00034, 0.00043, 0.00021 ]
iteration_trisection = [0.00091, 0.00107, 0.00034 , 0.01217, 0.00300]
iteration_regula = [0.00859, 0.00847, 0.00608 , 0.00941, 0.00311]
iteration_newton = [0.00026 , 0.00036, 0.00043, 0.00041 , 0.00311]
iteration_hybrid_bisection_regula = [0.00111, 0.00582, 0.00082, 0.00070, 0.00066 ]
iteration_hybrid_trisection_regula = [0.00277, 0.00438, 0.00226, 0.00056, 0.00288 ]


# Membuat plot
plt.figure(figsize=(10, 6))

# Plot untuk setiap metode
plt.plot(problems, iteration_bisection, linestyle='--', marker='o', color='blue', label='Bisection')
plt.plot(problems, iteration_trisection, linestyle='--', marker='o', color='orange', label='Trisection')
#plt.plot(problems, iteration_regula, linestyle='--', marker='o', color='green', label='Regula Falsi')
#plt.plot(problems, iteration_newton, linestyle='--', marker='o', color='red', label='Newton-Raphson')
#plt.plot(problems, iteration_hybrid_bisection_regula, linestyle='-', marker='o', color='purple', label='Hybrid Bisection-Regula Falsi')
plt.plot(problems, iteration_hybrid_trisection_regula, linestyle='--', marker='o', color='brown', label='Hybrid Trisection-Regula Falsi')

# Menambahkan label pada setiap titik data
for i, value in enumerate(iteration_bisection):
    plt.annotate(f"{value}", (problems[i], iteration_bisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='blue')

for i, value in enumerate(iteration_trisection):
    plt.annotate(f"{value}", (problems[i], iteration_trisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='orange')

#for i, value in enumerate(iteration_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='green')

#for i, value in enumerate(iteration_newton):
 #   plt.annotate(f"{value}", (problems[i], iteration_newton[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='red')

#for i, value in enumerate(iteration_hybrid_bisection_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_hybrid_bisection_regula[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='purple')

for i, value in enumerate(iteration_hybrid_trisection_regula):
    plt.annotate(f"{value}", (problems[i], iteration_hybrid_trisection_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='brown')

# Menambahkan judul dan label sumbu
plt.title('Perbandingan Average Run Time metode algoritma Bisection,Trisection dan hybrid Trisection-regula falsi Fungsi Trigonometri', fontsize=16, pad=20)
plt.xlabel('Fungsi(f)', fontsize=14, labelpad=15)
plt.ylabel('Average Run Time (s)', fontsize=14, labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Menyesuaikan layout
plt.tight_layout()

# Menampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data masalah (problems) dan iterasi untuk setiap metode
problems = ['F_8', 'F_9', 'F_10', 'F_13', 'F_15']
iteration_bisection = [0.00031, 0.00022, 0.00034, 0.00043, 0.00021 ]
iteration_trisection = [0.00091, 0.00107, 0.00034 , 0.01217, 0.00300]
iteration_regula = [0.00859, 0.00847, 0.00608 , 0.00941, 0.00311]
iteration_newton = [0.00026 , 0.00036, 0.00043, 0.00041 , 0.00311]
iteration_hybrid_bisection_regula = [0.00111, 0.00582, 0.00082, 0.00070, 0.00066 ]
iteration_hybrid_trisection_regula = [0.00277, 0.00438, 0.00226, 0.00056, 0.00288 ]


# Membuat plot
plt.figure(figsize=(10, 6))

# Plot untuk setiap metode
#plt.plot(problems, iteration_bisection, linestyle='--', marker='o', color='blue', label='Bisection')
#plt.plot(problems, iteration_trisection, linestyle='--', marker='o', color='orange', label='Trisection')
plt.plot(problems, iteration_regula, linestyle='--', marker='o', color='green', label='Regula Falsi')
plt.plot(problems, iteration_newton, linestyle='--', marker='o', color='red', label='Newton-Raphson')
plt.plot(problems, iteration_hybrid_bisection_regula, linestyle='-', marker='o', color='purple', label='Hybrid Bisection-Regula Falsi')
#plt.plot(problems, iteration_hybrid_trisection_regula, linestyle='--', marker='o', color='brown', label='Hybrid Trisection-Regula Falsi')

# Menambahkan label pada setiap titik data
#for i, value in enumerate(iteration_bisection):
 #   plt.annotate(f"{value}", (problems[i], iteration_bisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='blue')

#for i, value in enumerate(iteration_trisection):
 #   plt.annotate(f"{value}", (problems[i], iteration_trisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='orange')

for i, value in enumerate(iteration_regula):
    plt.annotate(f"{value}", (problems[i], iteration_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='green')

for i, value in enumerate(iteration_newton):
    plt.annotate(f"{value}", (problems[i], iteration_newton[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='red')

for i, value in enumerate(iteration_hybrid_bisection_regula):
    plt.annotate(f"{value}", (problems[i], iteration_hybrid_bisection_regula[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='purple')

#for i, value in enumerate(iteration_hybrid_trisection_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_hybrid_trisection_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='brown')

# Menambahkan judul dan label sumbu
plt.title('Perbandingan Average Run Time metode algoritma Regula Falsi, Newton Raphson dan hybrid bisection-regula falsi Fungsi Trigonometri', fontsize=16, pad=20)
plt.xlabel('Fungsi(f)', fontsize=14, labelpad=15)
plt.ylabel('Average Run Time (s)', fontsize=14, labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Menyesuaikan layout
plt.tight_layout()

# Menampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data masalah (problems) dan iterasi untuk setiap metode
problems = ['F_8', 'F_9', 'F_10', 'F_13', 'F_15']
iteration_bisection = [0.00031, 0.00022, 0.00034, 0.00043, 0.00021 ]
iteration_trisection = [0.00091, 0.00107, 0.00034 , 0.01217, 0.00300]
iteration_regula = [0.00859, 0.00847, 0.00608 , 0.00941, 0.00311]
iteration_newton = [0.00026 , 0.00036, 0.00043, 0.00041 , 0.00311]
iteration_hybrid_bisection_regula = [0.00111, 0.00582, 0.00082, 0.00070, 0.00066 ]
iteration_hybrid_trisection_regula = [0.00277, 0.00438, 0.00226, 0.00056, 0.00288 ]


# Membuat plot
plt.figure(figsize=(10, 6))

# Plot untuk setiap metode
#plt.plot(problems, iteration_bisection, linestyle='--', marker='o', color='blue', label='Bisection')
#plt.plot(problems, iteration_trisection, linestyle='--', marker='o', color='orange', label='Trisection')
plt.plot(problems, iteration_regula, linestyle='--', marker='o', color='green', label='Regula Falsi')
plt.plot(problems, iteration_newton, linestyle='--', marker='o', color='red', label='Newton-Raphson')
#plt.plot(problems, iteration_hybrid_bisection_regula, linestyle='-', marker='o', color='purple', label='Hybrid Bisection-Regula Falsi')
plt.plot(problems, iteration_hybrid_trisection_regula, linestyle='--', marker='o', color='brown', label='Hybrid Trisection-Regula Falsi')

# Menambahkan label pada setiap titik data
#for i, value in enumerate(iteration_bisection):
 #   plt.annotate(f"{value}", (problems[i], iteration_bisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='blue')

#for i, value in enumerate(iteration_trisection):
 #   plt.annotate(f"{value}", (problems[i], iteration_trisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='orange')

for i, value in enumerate(iteration_regula):
    plt.annotate(f"{value}", (problems[i], iteration_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='green')

for i, value in enumerate(iteration_newton):
    plt.annotate(f"{value}", (problems[i], iteration_newton[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='red')

#for i, value in enumerate(iteration_hybrid_bisection_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_hybrid_bisection_regula[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='purple')

for i, value in enumerate(iteration_hybrid_trisection_regula):
    plt.annotate(f"{value}", (problems[i], iteration_hybrid_trisection_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='brown')

# Menambahkan judul dan label sumbu
plt.title('Perbandingan Average Run Time metode algoritma Regula Falsi, Newton Raphson dan hybrid Trisection-regula falsi Fungsi Trigonometri', fontsize=16, pad=20)
plt.xlabel('Fungsi(f)', fontsize=14, labelpad=15)
plt.ylabel('Average Run Time (s)', fontsize=14, labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Menyesuaikan layout
plt.tight_layout()

# Menampilkan plot
plt.show()

# %% [markdown]
# ## Fubgsi Polinomial

# %%
import matplotlib.pyplot as plt

# Data masalah (problems) dan iterasi untuk setiap metode
problems = ['F_1', 'F_2', 'F_3', 'F_4', 'F_5', 'F_6', 'F_11']
iteration_bisection = [0.00509, 0.00039, 0.00215, 0.00020, 0.00022, 0.00025, 0.00026 ]
iteration_trisection = [ 0.00655, 0.01501, 0.01325, 0.00320, 0.01313, 0.00828, 0.00108]
iteration_regula = [0.00661, 0.01878, 0.00980, 0.00154, 0.00612, 0.00830, 0.01050]
iteration_newton = [0.00046, 0.00040, 0.00045, 0.00041, 0.00046, 0.00029, 0.00024]
iteration_hybrid_bisection_regula = [ 0.0044, 0.00354, 0.00096, 0.00408, 0.00178, 0.00155, 0.01050]
iteration_hybrid_trisection_regula = [ 0.00057, 0.00628, 0.00030, 0.00018, 0.00039, 0.00077, 0.00358 ]


# Membuat plot
plt.figure(figsize=(10, 6))

# Plot untuk setiap metode
plt.plot(problems, iteration_bisection, linestyle='--', marker='o', color='blue', label='Bisection')
plt.plot(problems, iteration_trisection, linestyle='--', marker='o', color='orange', label='Trisection')
#plt.plot(problems, iteration_regula, linestyle='--', marker='o', color='green', label='Regula Falsi')
#plt.plot(problems, iteration_newton, linestyle='--', marker='o', color='red', label='Newton-Raphson')
plt.plot(problems, iteration_hybrid_bisection_regula, linestyle='-', marker='o', color='purple', label='Hybrid Bisection-Regula Falsi')
#plt.plot(problems, iteration_hybrid_trisection_regula, linestyle='--', marker='o', color='brown', label='Hybrid Trisection-Regula Falsi')

# Menambahkan label pada setiap titik data
for i, value in enumerate(iteration_bisection):
    plt.annotate(f"{value}", (problems[i], iteration_bisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='blue')

for i, value in enumerate(iteration_trisection):
    plt.annotate(f"{value}", (problems[i], iteration_trisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='orange')

#for i, value in enumerate(iteration_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='green')

#for i, value in enumerate(iteration_newton):
 #   plt.annotate(f"{value}", (problems[i], iteration_newton[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='red')

for i, value in enumerate(iteration_hybrid_bisection_regula):
    plt.annotate(f"{value}", (problems[i], iteration_hybrid_bisection_regula[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='purple')

#for i, value in enumerate(iteration_hybrid_trisection_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_hybrid_trisection_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='brown')

# Menambahkan judul dan label sumbu
plt.title('Perbandingan Average Run Time metode algoritma Bisection,Trisection dan hybrid bisection-regula falsi Fungsi Polinomial', fontsize=16, pad=20)
plt.xlabel('Fungsi(f)', fontsize=14, labelpad=15)
plt.ylabel('Average Run Time (s)', fontsize=14, labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Menyesuaikan layout
plt.tight_layout()

# Menampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data masalah (problems) dan iterasi untuk setiap metode
problems = ['F_1', 'F_2', 'F_3', 'F_4', 'F_5', 'F_6', 'F_11']
iteration_bisection = [0.00509, 0.00039, 0.00215, 0.00020, 0.00022, 0.00025, 0.00026 ]
iteration_trisection = [ 0.00655, 0.01501, 0.01325, 0.00320, 0.01313, 0.00828, 0.00108]
iteration_regula = [0.00661, 0.01878, 0.00980, 0.00154, 0.00612, 0.00830, 0.01050]
iteration_newton = [0.00046, 0.00040, 0.00045, 0.00041, 0.00046, 0.00029, 0.00024]
iteration_hybrid_bisection_regula = [ 0.0044, 0.00354, 0.00096, 0.00408, 0.00178, 0.00155, 0.01050]
iteration_hybrid_trisection_regula = [ 0.00057, 0.00628, 0.00030, 0.00018, 0.00039, 0.00077, 0.00358 ]


# Membuat plot
plt.figure(figsize=(10, 6))

# Plot untuk setiap metode
plt.plot(problems, iteration_bisection, linestyle='--', marker='o', color='blue', label='Bisection')
plt.plot(problems, iteration_trisection, linestyle='--', marker='o', color='orange', label='Trisection')
#plt.plot(problems, iteration_regula, linestyle='--', marker='o', color='green', label='Regula Falsi')
#plt.plot(problems, iteration_newton, linestyle='--', marker='o', color='red', label='Newton-Raphson')
#plt.plot(problems, iteration_hybrid_bisection_regula, linestyle='-', marker='o', color='purple', label='Hybrid Bisection-Regula Falsi')
plt.plot(problems, iteration_hybrid_trisection_regula, linestyle='--', marker='o', color='brown', label='Hybrid Trisection-Regula Falsi')

# Menambahkan label pada setiap titik data
for i, value in enumerate(iteration_bisection):
    plt.annotate(f"{value}", (problems[i], iteration_bisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='blue')

for i, value in enumerate(iteration_trisection):
    plt.annotate(f"{value}", (problems[i], iteration_trisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='orange')

#for i, value in enumerate(iteration_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='green')

#for i, value in enumerate(iteration_newton):
 #   plt.annotate(f"{value}", (problems[i], iteration_newton[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='red')

#for i, value in enumerate(iteration_hybrid_bisection_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_hybrid_bisection_regula[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='purple')

for i, value in enumerate(iteration_hybrid_trisection_regula):
    plt.annotate(f"{value}", (problems[i], iteration_hybrid_trisection_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='brown')

# Menambahkan judul dan label sumbu
plt.title('Perbandingan Average Run Time metode algoritma Bisection,Trisection dan hybrid Trisection-regula falsi Fungsi Polinomial', fontsize=16, pad=20)
plt.xlabel('Fungsi(f)', fontsize=14, labelpad=15)
plt.ylabel('Average Run Time (s)', fontsize=14, labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Menyesuaikan layout
plt.tight_layout()

# Menampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data masalah (problems) dan iterasi untuk setiap metode
problems = ['F_1', 'F_2', 'F_3', 'F_4', 'F_5', 'F_6', 'F_11']
iteration_bisection = [0.00509, 0.00039, 0.00215, 0.00020, 0.00022, 0.00025, 0.00026 ]
iteration_trisection = [ 0.00655, 0.01501, 0.01325, 0.00320, 0.01313, 0.00828, 0.00108]
iteration_regula = [0.00661, 0.01878, 0.00980, 0.00154, 0.00612, 0.00830, 0.01050]
iteration_newton = [0.00046, 0.00040, 0.00045, 0.00041, 0.00046, 0.00029, 0.00024]
iteration_hybrid_bisection_regula = [ 0.0044, 0.00354, 0.00096, 0.00408, 0.00178, 0.00155, 0.01050]
iteration_hybrid_trisection_regula = [ 0.00057, 0.00628, 0.00030, 0.00018, 0.00039, 0.00077, 0.00358 ]


# Membuat plot
plt.figure(figsize=(10, 6))

# Plot untuk setiap metode
#plt.plot(problems, iteration_bisection, linestyle='--', marker='o', color='blue', label='Bisection')
#plt.plot(problems, iteration_trisection, linestyle='--', marker='o', color='orange', label='Trisection')
plt.plot(problems, iteration_regula, linestyle='--', marker='o', color='green', label='Regula Falsi')
plt.plot(problems, iteration_newton, linestyle='--', marker='o', color='red', label='Newton-Raphson')
plt.plot(problems, iteration_hybrid_bisection_regula, linestyle='-', marker='o', color='purple', label='Hybrid Bisection-Regula Falsi')
#plt.plot(problems, iteration_hybrid_trisection_regula, linestyle='--', marker='o', color='brown', label='Hybrid Trisection-Regula Falsi')

# Menambahkan label pada setiap titik data
#for i, value in enumerate(iteration_bisection):
 #   plt.annotate(f"{value}", (problems[i], iteration_bisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='blue')

#for i, value in enumerate(iteration_trisection):
 #   plt.annotate(f"{value}", (problems[i], iteration_trisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='orange')

for i, value in enumerate(iteration_regula):
    plt.annotate(f"{value}", (problems[i], iteration_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='green')

for i, value in enumerate(iteration_newton):
    plt.annotate(f"{value}", (problems[i], iteration_newton[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='red')

for i, value in enumerate(iteration_hybrid_bisection_regula):
    plt.annotate(f"{value}", (problems[i], iteration_hybrid_bisection_regula[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='purple')

#for i, value in enumerate(iteration_hybrid_trisection_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_hybrid_trisection_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='brown')

# Menambahkan judul dan label sumbu
plt.title('Perbandingan Average Run Time metode algoritma Regula Falsi,Newton Raphson dan hybrid bisection-regula falsi Fungsi Polinomial', fontsize=16, pad=20)
plt.xlabel('Fungsi(f)', fontsize=14, labelpad=15)
plt.ylabel('Average Run Time (s)', fontsize=14, labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Menyesuaikan layout
plt.tight_layout()

# Menampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data masalah (problems) dan iterasi untuk setiap metode
problems = ['F_1', 'F_2', 'F_3', 'F_4', 'F_5', 'F_6', 'F_11']
iteration_bisection = [0.00509, 0.00039, 0.00215, 0.00020, 0.00022, 0.00025, 0.00026 ]
iteration_trisection = [ 0.00655, 0.01501, 0.01325, 0.00320, 0.01313, 0.00828, 0.00108]
iteration_regula = [0.00661, 0.01878, 0.00980, 0.00154, 0.00612, 0.00830, 0.01050]
iteration_newton = [0.00046, 0.00040, 0.00045, 0.00041, 0.00046, 0.00029, 0.00024]
iteration_hybrid_bisection_regula = [ 0.0044, 0.00354, 0.00096, 0.00408, 0.00178, 0.00155, 0.01050]
iteration_hybrid_trisection_regula = [ 0.00057, 0.00628, 0.00030, 0.00018, 0.00039, 0.00077, 0.00358 ]


# Membuat plot
plt.figure(figsize=(10, 6))

# Plot untuk setiap metode
#plt.plot(problems, iteration_bisection, linestyle='--', marker='o', color='blue', label='Bisection')
#plt.plot(problems, iteration_trisection, linestyle='--', marker='o', color='orange', label='Trisection')
plt.plot(problems, iteration_regula, linestyle='--', marker='o', color='green', label='Regula Falsi')
plt.plot(problems, iteration_newton, linestyle='--', marker='o', color='red', label='Newton-Raphson')
#plt.plot(problems, iteration_hybrid_bisection_regula, linestyle='-', marker='o', color='purple', label='Hybrid Bisection-Regula Falsi')
plt.plot(problems, iteration_hybrid_trisection_regula, linestyle='--', marker='o', color='brown', label='Hybrid Trisection-Regula Falsi')

# Menambahkan label pada setiap titik data
#for i, value in enumerate(iteration_bisection):
 #   plt.annotate(f"{value}", (problems[i], iteration_bisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='blue')

#for i, value in enumerate(iteration_trisection):
 #   plt.annotate(f"{value}", (problems[i], iteration_trisection[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='orange')

for i, value in enumerate(iteration_regula):
    plt.annotate(f"{value}", (problems[i], iteration_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='green')

for i, value in enumerate(iteration_newton):
    plt.annotate(f"{value}", (problems[i], iteration_newton[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='red')

#for i, value in enumerate(iteration_hybrid_bisection_regula):
 #   plt.annotate(f"{value}", (problems[i], iteration_hybrid_bisection_regula[i]), textcoords="offset points",  xytext=(0, 5), ha='center', fontsize=8, color='purple')

for i, value in enumerate(iteration_hybrid_trisection_regula):
    plt.annotate(f"{value}", (problems[i], iteration_hybrid_trisection_regula[i]), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=8, color='brown')

# Menambahkan judul dan label sumbu
plt.title('Perbandingan Average Run Time metode algoritma Regula Falsi,Newton Raphson dan hybrid Trisection-regula falsi Fungsi Polinomial', fontsize=16, pad=20)
plt.xlabel('Fungsi(f)', fontsize=14, labelpad=15)
plt.ylabel('Average Run Time (s)', fontsize=14, labelpad=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Menyesuaikan layout
plt.tight_layout()

# Menampilkan plot
plt.show()
